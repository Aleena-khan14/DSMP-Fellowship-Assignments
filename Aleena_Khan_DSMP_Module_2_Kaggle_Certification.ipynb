# %% [markdown]
# <a href="https://colab.research.google.com/github/Aleena-khan14/DSMP-Fellowship-Assignments/blob/main/Aleena_Khan_DSMP_Module_2_Kaggle_Certification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![download (1).png](data:image/png;base64,...)

# %% [markdown]
# ### 🚀 My Short Introduction! 🎓
#
# - Aleena Khan is an aspiring data professional at **Data Seekho**.
# - 📚 Learning **Python, SQL, Machine Learning**, and more through **Data Seekho’s** courses.
# - 💻 Engaging in **hands-on projects** and learning from **industry experts**.
# - 🌟 Part of **Data Seekho’s supportive community**, aiming for top 1% in data.
# - 🎯 Preparing for a **successful career** in Data Science with **Data Seekho**.

# %% [markdown]
# My name is Aleena Khan and I am a technical consultant in data seekho. My aim is to become Data Scientist. I am currently enrolled in Data Seekho Mastery Program and this is my project of Module 1. I am very excited to complete it.

# %% [markdown]
# Here attached is my certification of Pandas From Kaggle

# %% [markdown]
# ![Aleena Khan - Pandas.png](data:image/png;base64,...)
